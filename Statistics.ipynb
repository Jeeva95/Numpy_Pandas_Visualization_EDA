# %% [markdown]
# # 1. Correlation +1 means?
# a. No relation b. Negative relation c. Perfect positive relation d. Weak relation
#
# Answer :- Perfect positive relation

# %% [markdown]
# # 2. Range of {5,8,10,14,18}?
# a. 10 b. 12 c. 13 d. 15
#
# Answer :- 13

# %% [markdown]
# # 3. Which measure is most affected by extreme values?
# a. Median b. Mode c. Mean d. Quartile
#
# Answer :- Mean

# %% [markdown]
# # 4. Mode of {1,3,3,7,8,3,9}?
# a. 1 b. 3 c. 7 d. 9
#
# Answer :- 3

# %% [markdown]
# # 5. Z test uses?
# a. t distribution b. Normal distribution c. Chi-square d. F distribution
#
# Answer :-  Normal distribution

# %% [markdown]
# # 6. Quartiles divide data into?
# a. 2 b. 3 c. 4 d. 5
#
# Answer :- 4

# %% [markdown]
# # 7. Chi-square used for?
# a. Numeric b. Categorical c. Regression d. Mean
#
# Answer :- Categorical

# %% [markdown]
# # 8. F test compares?
# a. Means b. Medians c. Variances d. Modes
#
# Answer :- Variances

# %% [markdown]
# # 9. Confidence interval gives?
# a. Exact value b. Range of parameter c. Mean only d. Std only
#
# Answer :- Range of parameter

# %% [markdown]
# # 10. 90th percentile means?
# a. Score 90 marks b. Better than 90% students c. 90% failed d. Score 10%
#
# Answer :- Better than 90% students

# %% [markdown]
# # 11. ANOVA uses which statistic?
# a. t b. z c. f d. Chi-square
#
# Answer :- f

# %% [markdown]
# # 12. Z test used when?
# a. Small sample b. Variance unknown c. Large sample known variance d. Zero sample
#
# Answer :- Variance unknown

# %% [markdown]
# # 13. Correlation measures?
# a. Central tendency b. Relationship between variables c. Spread d. Probability
#
# Answer :- Relationship between variables

# %% [markdown]
# # 14. T test distribution?
# a. Normal b. Chi-square c. t distribution d. F distribution
#
# Answer :- t distribution

# %% [markdown]
# # 15. Second quartile equals?
# a. Mean b. Median c. Mode d. Range
#
# Answer :- Median

# %% [markdown]
# # 16. Variance measures?
# a. Central tendency b. Spread of data c. Shape of distribution d. Frequency
#
# Answer :- Spread of data

# %% [markdown]
# # 17. Outliers are values that?
# a. Near mean b. Repeated c. Significantly different d. Equal to median
#
# Answer :- Significantly different

# %% [markdown]
# # 18. Outliers detected using?
# a. Mean rule b. IQR method c. Variance rule d. Range rule
#
# Answer :- IQR method

# %% [markdown]
# # 19. Standard deviation is?
# a. Square of variance b. Square root of variance c. Half variance d. Double variance
#
# Answer :- Square root of variance

# %% [markdown]
# # 20. One way ANOVA compares?
# a. Two means b. Three or more means c. Two variances d. Two correlations
#
# Answer :- Three or more means

# %% [markdown]
# # 21. Correlation close to 0 means?
# a. Strong relation b. Weak relation c. Perfect relation c. Negative relation
#
# Answer :- Weak relation

# %% [markdown]
# # 22. Median of {2,5,7,9,11}?
# a. 5 b. 7 c. 9 d. 6
#
# Answer :- 7

# %% [markdown]
# # 23. Chi-square tests?
# a. Independence b. Mean difference c. Variance equality d. Correlation
#
# Answer :- Independence

# %% [markdown]
# # 24. ANOVA stands for?
# a. Analysis variable outcome b. Analysis of variance c. Average numeric value d. Analytical variance operation
#
# Answer :- Analysis of variance

# %% [markdown]
# # 25. Inferential statistics used to?
# a. Describe data b. Predict population c. Organize data d. Plot graphs
#
# Answer :- Predict population

# %% [markdown]
# # 26. 50th percentile equals?
# a. Mode b. Median c. Mean d. Variance
#
# Answer :- Median

# %% [markdown]
# # 27. Population refers to?
# a. Subset b. Entire group c. Sample d. Random values
#
# Answer :- Entire group

# %% [markdown]
# # 28. T test used when?
# a. Small sample b. Variance known c. Large sample d. Mean=median
#
# Answer :- Small sample

# %% [markdown]
# # 29. The mean of 4,8,6,10,12 is?
# a. 7 b. 8 c. 9 d. 10
#
# Answer :-
